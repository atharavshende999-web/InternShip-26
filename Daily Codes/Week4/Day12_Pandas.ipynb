# %%
#Pandas

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1D Data Structure in pandas

# %%
#Pandas Series

# %%
#Creating Series

# %%
import pandas as pd

# %%
s=pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
series=pd.Series([10,'ABC','Pune'])

# %%
series
# Out:
# 0      10
# 1     ABC
# 2    Pune
# dtype: object

# %%
#With Index

# %%
s=pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s=pd.Series(['Atharv',18,99],index=['Name','Age','Mark'])

# %%
s
# Out:
# Name    Atharv
# Age         18
# Mark        99
# dtype: object

# %%
# From Dictionary

# %%
data={'name':'abc','mark':99,'age':18}

# %%
s=pd.Series(data)

# %%
s
# Out:
# name    abc
# mark     99
# age      18
# dtype: object

# %%
data={'Name':'XYZ','Subject':'Python','Marks':100}

# %%
s=pd.Series(data)

# %%
s
# Out:
# Name          XYZ
# Subject    Python
# Marks         100
# dtype: object

# %%
s=pd.Series(5,index=[1,2,3,4,5])

# %%
s
# Out:
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# dtype: int64

# %%
s=pd.Series(index=[1,2,3,4,5,6,7,8,9])

# %%
s[:]=5

# %%
s
# Out:
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# 5    5.0
# 6    5.0
# 7    5.0
# 8    5.0
# 9    5.0
# dtype: float64

# %%
p=pd.Series([10,20,30],index=['a','b','c'])

# %%
p
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
p.values
# Out:
# array([10, 20, 30])

# %%
p.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
p.dtype
# Out:
# dtype('int64')

# %%
p.shape
# Out:
# (3,)

# %%
# Data Mantupulation

# %%
series=pd.Series([1,2,3])

# %%
print(series* 3)
# Out:
# 0    3
# 1    6
# 2    9
# dtype: int64

# %%
# Handling missing value

# %%
s=pd.Series([1,None,3])

# %%
s
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    1.0
# 2    3.0
# dtype: float64

# %%
s.fillna(0)
# Out:
# 0    1.0
# 1    0.0
# 2    3.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
# indexing

# %%
s=pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
s['c']
# Out:
# np.int64(30)

# %%
s['c']=23

# %%
s
# Out:
# a    10
# b    20
# c    23
# dtype: int64

# %%
'''
Dataframe=>2D data is mutable,
size is mutable
data is heterogenous
'''
# Out:
# '\nDataframe=>2D data is mutable,\nsize is mutable\ndata is heterogenous\n'

# %%
import pandas as pd

# %%
roll=pd.Series([1,2,3])
name=pd.Series(['ABC','PQR','LMN'])
marks=pd.Series([99,89,87])

# %%
df=pd.DataFrame({
    'ID':roll,
    'Name':name,
    'Marks':marks
})

# %%
df
# Out:
#    ID Name  Marks
# 0   1  ABC     99
# 1   2  PQR     89
# 2   3  LMN     87

# %%
df.shape
# Out:
# (3, 3)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 9

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['ID']
# Out:
# 0    1
# 1    2
# 2    3
# Name: ID, dtype: int64

# %%
df['Name']
# Out:
# 0    ABC
# 1    PQR
# 2    LMN
# Name: Name, dtype: object

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Marks'], dtype='object')

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Marks'], dtype='object')

# %%
df.values
# Out:
# array([[1, 'ABC', 99],
#        [2, 'PQR', 89],
#        [3, 'LMN', 87]], dtype=object)

# %%
'''
url-> https://mitu.co.in/dataset

download all dataset starting with student
put them in the sample file folder as ur current working directory
'''
# Out:
# '\nurl-> https://mitu.co.in/dataset\n\ndownload all dataset starting with student\nput them in the sample file folder as ur current working directory\n'

# %%
pwd
# Out:
# 'C:\\Users\\athra'

# %%
df=pd.read_csv("student.csv")

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df=pd.read_csv("student1.csv")

# %%
df
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
col=['roll','Names','percentage','age']

# %%
df=pd.read_csv("student1.csv",names=col)

# %%
df
# Out:
#        roll Names  percentage  age
# 1      anil    TE       56.77   22
# 2      amit    TE       59.77   21
# 3    aniket    BE       76.88   19
# 4   ajinkya    TE       69.66   20
# 5      asha    TE       63.28   20
# 6    ayesha    BE       49.55   20
# 7      amar    BE       65.34   19
# 8     amita    BE       68.33   23
# 9      amol    TE       56.75   20
# 10    anmol    BE       78.66   21

# %%
df=pd.read_csv("student3.tsv",sep='\t')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21
