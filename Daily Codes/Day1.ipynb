# %% [markdown]
# # Day1 Topic

# %% [markdown]
# ## 1.Using print() fun

# %%
print("hello")
# Out:
# hello

# %%
a=12
print(a)
# Out:
# 12

# %%
a
# Out:
# 12

# %% [markdown]
# ## 2.Using Indentifier(User Defined Name)

# %%
num1=12
num3=34
num2=34

# %%
print(num1+num2+num3)
# Out:
# 80

# %% [markdown]
# ## 3.Learn with some Datatype

# %%
a=12
type(a)
# Out:
# int

# %%
b=45.67
print(type(b))
# Out:
# <class 'float'>

# %%
str="Hello"
type(str)
# Out:
# str

# %%
#Complex Number

# %%
comp=5+8j
print(comp)
# Out:
# (5+8j)

# %%
type(comp)
# Out:
# complex

# %% [markdown]
# ## 4.Perform Two Number Addition

# %%
a=122
b=455
print(a+b)
# Out:
# 577

# %% [markdown]
# ## 5.Just Add Two Number in single Line

# %%
a=122;b=56;c=a+b;print(c)
# Out:
# 178

# %% [markdown]
# ## 6.Print Some String with given Formate:-

# %%
#I Love 'Python' programming

# %%
set="I Love 'Python' programming"

# %%
print(set)
# Out:
# I Love 'Python' programming

# %%
#I Love "Python" programming

# %%
set="I Love "Python programming" "
# Out:
#   Cell In[37], line 1
#     set="I Love "Python programming" "
#                  ^
# SyntaxError: invalid syntax

# %%
set='I Love "Python programming" '

# %%
set
# Out:
# 'I Love "Python programming" '
