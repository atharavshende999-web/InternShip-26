# %% [markdown]
# # File Handling

# %%
#open the file

# %%
f=open('Sample.txt')

# %%
print(f) #memory Function of f object
# Out:
# <_io.TextIOWrapper name='Sample.txt' mode='r' encoding='cp1252'>

# %%
f.readable() #Check Whethere File is ready to read
# Out:
# True

# %%
f.readline()
# Out:
# 'This file contains basic information about a simple Python program designed to demonstrate file handling operations. \n'

# %%
f.readline()
# Out:
# 'The program allows the user to create a file, write data into it, and read the stored content.\n'

# %%
f.readline()
# Out:
# ''

# %%
f=open('Sample.txt')

# %%
f.readline(10)
# Out:
# 'This file '

# %%
f.readline(5)
# Out:
# 'conta'

# %%
#Check ReadLines

# %%
f=open('Sample.txt')

# %%
f.readlines(15)
# Out:
# ['This file contains basic information about a simple Python program designed to demonstrate file handling operations. \n']

# %%
f.readlines(15)
# Out:
# ['The program allows the user to create a file, write data into it, and read the stored content.\n']

# %%
f=open('Sample.txt')

# %%
data=f.readlines()

# %%
f=open('Sample.txt')

# %%
data=f.readlines()

# %%
for line in data:
    print(line)
# Out:
# This file contains basic information about a simple Python program designed to demonstrate file handling operations.
#
# The program allows the user to create a file, write data into it, and read the stored content.

# %%
#Convert the data in upper

# %%
for line in data:
    print(line.upper())
# Out:
# THIS FILE CONTAINS BASIC INFORMATION ABOUT A SIMPLE PYTHON PROGRAM DESIGNED TO DEMONSTRATE FILE HANDLING OPERATIONS.
#
# THE PROGRAM ALLOWS THE USER TO CREATE A FILE, WRITE DATA INTO IT, AND READ THE STORED CONTENT.

# %%
# read Function

# %%
f=open('Sample.txt')

# %%
data=f.read()

# %%
for i in data:
    print(i.upper())
# Out:
# T
# H
# I
# S
#
# F
# I
# L
# E
#
# C
# O
# N
# T
# A
# I
# N
# S
#
# B
# A
# S
# I
# C
#
# I
# N
# F
# O
# R
# M
# A
# T
# I
# O
# N
#
# A
# B
# O
# U
# T
#
# A
#
# S
# I
# M
# P
# L
# E
#
# P
# Y
# T
# H
# O
# N
#
# P
# R
# O
# G
# R
# A
# M
#
# D
# E
# S
# I
# G
# N
# E
# D
#
# T
# O
#
# D
# E
# M
# O
# N
# S
# T
# R
# A
# T
# E
#
# F
# I
# L
# E
#
# H
# A
# N
# D
# L
# I
# N
# G
#
# O
# P
# E
# R
# A
# T
# I
# O
# N
# S
# .
#
#
#
# T
# H
# E
#
# P
# R
# O
# G
# R
# A
# M
#
# A
# L
# L
# O
# W
# S
#
# T
# H
# E
#
# U
# S
# E
# R
#
# T
# O
#
# C
# R
# E
# A
# T
# E
#
# A
#
# F
# I
# L
# E
# ,
#
# W
# R
# I
# T
# E
#
# D
# A
# T
# A
#
# I
# N
# T
# O
#
# I
# T
# ,
#
# A
# N
# D
#
# R
# E
# A
# D
#
# T
# H
# E
#
# S
# T
# O
# R
# E
# D
#
# C
# O
# N
# T
# E
# N
# T
# .

# %%
f=open('Sample.txt')

# %%
text=f.read()

# %%
text
# Out:
# 'This file contains basic information about a simple Python program designed to demonstrate file handling operations. \nThe program allows the user to create a file, write data into it, and read the stored content.\n'

# %%
text.split()
# Out:
# ['This',
#  'file',
#  'contains',
#  'basic',
#  'information',
#  'about',
#  'a',
#  'simple',
#  'Python',
#  'program',
#  'designed',
#  'to',
#  'demonstrate',
#  'file',
#  'handling',
#  'operations.',
#  'The',
#  'program',
#  'allows',
#  'the',
#  'user',
#  'to',
#  'create',
#  'a',
#  'file,',
#  'write',
#  'data',
#  'into',
#  'it,',
#  'and',
#  'read',
#  'the',
#  'stored',
#  'content.']

# %%
m=open('Marathi.txt',encoding='utf-8')

# %%
print(m.read())
# Out:
# तुम्हाला वाचण्यासाठी किंवा स्टेटससाठी विविध प्रकारचा मराठी मजकूर खाली दिला आहे.१. प्रेरणादायी सुविचार (Motivational Quotes)"अपयशाची भीती बाळगण्यापेक्षा, प्रयत्नांचा आनंद घ्या."
# (प्रयत्न हेच यशाचे रहस्य आहे.)"कोणतीही गोष्ट अशक्य नसते, फक्त आपल्या इच्छित ध्येयापर्यंत पोहोचण्याची जिद्द हवी."२. आयुष्याशी निगडित (Life Status)"फोकस क्लीअर नसला की सगळं अंधुकच होऊन बसतं.
# मग तो फोटो असू दे किंवा आयुष्य.""मैत्री टिकण्यासाठी रोज बोलणं, भेटणं गरजेचं नसतं."

# %%
m.close()

# %%
m.readable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 m.readable()
#
# ValueError: I/O operation on closed file

# %%
#opening a file with context Manager

# %%
with open('Sample.txt') as f:
    data=f.read()

# %%
print(data)

# %%
f.close()

# %%
data

# %%
f=open('myfile.txt','w')

# %%
f.readable()

# %%
f.writable()

# %%
lines=['frodo took the ring.','he starting his journey to mount doom.']

# %%
f.writelines(lines)

# %%
sent="frodo took the ring. he started his journey to mount doom"

# %% [raw]
# f=open('myfile.txt','w')

# %%
f.write(sent)
f.close()

# %%
#Copy Content of one file to Another

# %%
f1=open('Sample.txt','r')
f2=open('myfile.txt','w')

# %%
contents=f1.read()
f2.write(contents)
f2.close()

# %%
#append

# %%
s=open("Sample.txt",'a')

# %%
s.write('Thank You!')
# Out:
# 10

# %%
s=open('Sample.txt','r')

# %%
s.readline()
# Out:
# 'This file contains basic information about a simple Python program designed to demonstrate file handling operations. \n'

# %%
s.tell()
# Out:
# 118

# %%
s.seek(10)
# Out:
# 10
