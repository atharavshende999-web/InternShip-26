# %% [markdown]
# # Basic String Function

# %%
#String

# %%
name="String"

# %%
name.lower()
# Out:
# 'string'

# %%
name
# Out:
# 'String'

# %%
name=name.lower()

# %%
name
# Out:
# 'string'

# %%
name.upper()
# Out:
# 'STRING'

# %%
name.title()
# Out:
# 'String'

# %%
name="Atharv"

# %%
name.swapcase()
# Out:
# 'aTHARV'

# %%
name.title()
# Out:
# 'Atharv'

# %%
n1="A"

# %%
n2="B"

# %%
name.isupper()  #if 1st letter is captial and all letter are small then it return False
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.title()
# Out:
# 'Atharv'

# %%
name
# Out:
# 'Atharv'

# %%
name="atharv"

# %%
name.title()
# Out:
# 'Atharv'

# %%
name
# Out:
# 'atharv'

# %%
name1="ok"

# %%
name2="123"
name3="0k123"

# %%
name1.isalpha() #it return true because it contain pure charater
# Out:
# True

# %%
name2.isalpha() #in string2 there is some number and no any pure alphabet so it return false
# Out:
# False

# %%
name3.isalpha() #it contain alphabet and digit but there is no any pure alphabet
# Out:
# False

# %%
name.isdigit()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit() #it check whether string contain pure numerical so it return true else false
# Out:
# False

# %%
name3.isalnum()
# Out:
# True

# %%
name1.isalnum() #combination of alphabet and number
# Out:
# True

# %%
n="$%%"

# %%
n.isalnum()
# Out:
# False

# %%
name=" Pune"

# %%
print(name)
# Out:
# Pune

# %%
name.startswith("P")
# Out:
# True

# %%
name.endswith("p")
# Out:
# False

# %%
name.endswith("")
# Out:
# True

# %%
name.endswith("e")
# Out:
# True

# %%
name.endswith(" ")
# Out:
# False

# %%
name=" Pune "

# %%
name.lstrip()
# Out:
# 'Pune '

# %%
name.rstrip()
# Out:
# ' Pune'

# %%
name.strip() #Working like triming left amd right whitespace
# Out:
# 'Pune'

# %%
len(name) #It also Count Whitespace
# Out:
# 6

# %%
name.replace('u','oo') #If there is multiple letter then it replace first occurenece letter
# Out:
# ' Poone '

# %% [markdown]
# #Operatoes

# %% [markdown]
# # Operatots

# %%
#arithmetic

# %%
a=12
b=34

# %%
a+b
# Out:
# 46

# %%
a-b
# Out:
# -22

# %%
a*b
# Out:
# 408

# %%
b/a
# Out:
# 2.8333333333333335

# %%
a//b
# Out:
# 0

# %%
a*b
# Out:
# 408

# %%
a**b
# Out:
# 4922235242952026704037113243122008064

# %%
b//a
# Out:
# 2

# %%
b%a
# Out:
# 10

# %% [markdown]
# # Assignment Operator

# %%
x=5

# %%
x
# Out:
# 5

# %%
x=x+6

# %%
x
# Out:
# 11

# %%
z+=2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 z+=2
#
# NameError: name 'z' is not defined

# %%
x+=5

# %%
x
# Out:
# 16

# %%
x-=6

# %%
x
# Out:
# 10

# %%
x*=3

# %%
x
# Out:
# 30

# %%
#comparison

# %%
x=12
y=56

# %%
x>y
# Out:
# False

# %%
x<y
# Out:
# True

# %%
x>=y
# Out:
# False

# %%
x<=y
# Out:
# True

# %%
x!=y
# Out:
# True

# %%
x==y
# Out:
# False

# %% [markdown]
# # Logical Operator

# %%
a=True

# %%
b=False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %% [markdown]
# # identity operator -> is,is not

# %%
a=12
b=23

# %%
a is b
# Out:
# False

# %%
a=5
b=5

# %%
a is b
# Out:
# True

# %%
id(a), id(b)
# Out:
# (140703216477224, 140703216477224)

# %%
a=[1,3]

# %%
b=[1,3]

# %%
a is b
# Out:
# False

# %%
id(a),id(b)
# Out:
# (1887992412160, 1887993346368)

# %%
a is not b
# Out:
# True

# %%
z=a

# %%
z
# Out:
# [1, 3]

# %%
a=[1,3,4]

# %%
z
# Out:
# [1, 3]

# %%
id(a),id(z)
# Out:
# (1887993336576, 1887992412160)

# %%
b.append(10)

# %%
b
# Out:
# [1, 3, 10]

# %%
a.append(10)

# %%
a
# Out:
# [1, 3, 4, 10]

# %%
z
# Out:
# [1, 3]

# %%
z=a

# %%
z
# Out:
# [1, 3, 4, 10]

# %%
a.append(2)

# %%
a
# Out:
# [1, 3, 4, 10, 2]

# %%
z
# Out:
# [1, 3, 4, 10, 2]

# %% [markdown]
# # Membership Operator->in,not in

# %%
a=[1,2,4]

# %%
b=[1,3]

# %%
a in b
# Out:
# False

# %%
a not in b
# Out:
# True

# %%
1 in a
# Out:
# True

# %%
2 in a
# Out:
# True

# %%
2 not in a
# Out:
# False

# %%
l1=[1,3,4]
l2=[1,3,4,5]
l3=[1,5,6,]

# %%
l1,l2 in l3
# Out:
# ([1, 3, 4], False)

# %% [markdown]
# #### Precedence and association

# %%
#BODMAS

# %%
5+2-10
# Out:
# -3

# %%
2**2**3 ## Right Asscoitation only fot raosed to operator
# Out:
# 256

# %%
2**8//2
# Out:
# 128

# %%
name="greet"
marks=76.34

# %%
print("my name is",name,"and marks are",marks)
# Out:
# my name is greet and marks are 76.34

# %%
print("my name is %s and marks are %i" %(name,marks))
# Out:
# my name is greet and marks are 76

# %%
print(f"my name is {name} and marks are{marks}")
# Out:
# my name is greet and marks are76.34

# %%
dir(name);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # dir and help
# ----> 2 dir(name);
#
# NameError: name 'name' is not defined

# %%
help(name.lstrip)
# Out:
# Help on built-in function lstrip:
#
# lstrip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %% [markdown]
# # ASCII

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(66)
# Out:
# 'B'

# %%
chr(35)
# Out:
# '#'

# %% [raw]
# chr(34)

# %%
chr(67)
# Out:
# 'C'

# %%
# type casting

# %%
num1=34
num2=44.56
num3="ok"

# %%
type(num1)
# Out:
# int

# %%
float(num1)
# Out:
# 34.0

# %%
int(num2)
# Out:
# 44

# %%
str(num1)
# Out:
# '34'

# %%
str(num2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 str(num2)
#
# NameError: name 'num2' is not defined

# %%
str(num2)
# Out:
# '44.56'

# %%
int(num3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 int(num3)
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %%
a=input("enter value")
# Out:
# enter value 5

# %%
print("ok")
# Out:
# ok

# %%
#write a program using user input of 2 numbers

# %%
a=int(input("enter a"))
b=int(input("enter b"))

print(a+b)
# Out:
# enter a 4
# enter b 6
# 10

# %%
second=int(input("enter the seconds"))

minutes=(second%3600)//60
hour=second//3600
second=second%60

print(hour,":",minutes,":",second)
# Out:
# enter the seconds 150
# 0 : 2 : 30
