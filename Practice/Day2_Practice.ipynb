# %% [markdown]
# # Day2 Practice

# %% [markdown]
# # String Function

# %%
name1="ATHARV"

# %% [markdown]
# ### Measure the Length of String

# %%
len(name1)
# Out:
# 6

# %% [markdown]
# ###### Check Whether the String is Upper or Lower

# %%
name1.isupper()
# Out:
# True

# %%
name1.islower()
# Out:
# False

# %% [markdown]
# ### Convert String in lower and upper Case

# %%
name1=name1.lower()

# %%
name1
# Out:
# 'atharv'

# %% [markdown]
# name1=name1.upper()

# %%
name1
# Out:
# 'ATHARV'

# %% [markdown]
# ### Check Whether String is starts and ends with specified string

# %%
name1.startswith('A')
# Out:
# True

# %%
name1.startswith('a')
# Out:
# False

# %%
name1.endswith('v')
# Out:
# False

# %%
name1.endswith('V')
# Out:
# True

# %% [markdown]
# ### Replace String

# %%
name1.replace('A','a')
# Out:
# 'aTHaRV'

# %% [markdown]
# ### Triming the String

# %%
name1=' Atharv  '

# %%
name1.lstrip()
# Out:
# 'Atharv  '

# %%
name1.rstrip()
# Out:
# ' Atharv'

# %%
name1.strip()
# Out:
# 'Atharv'

# %% [markdown]
# ### Check Whether The Srting Contain Alphabet or Digit

# %%
name1="Atharv"

# %%
name1.isalpha()
# Out:
# True

# %%
name1.isnumeric()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name1="Pass123"

# %%
name1.isalnum()
# Out:
# True

# %% [markdown]
# ### Dir and Help

# %%
name="String"

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
name="  Atharv"

# %%
len(name)
# Out:
# 8

# %%
help(len(name))
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating-point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
# ...

# %% [markdown]
# ### Type Casting

# %%
a=12
b=34.56
c="Atharv"

# %%
float(a)
# Out:
# 12.0

# %%
int(b)
# Out:
# 34

# %%
int(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 int(c)
#
# ValueError: invalid literal for int() with base 10: 'Atharv'

# %% [markdown]
# ### Operator

# %%
##Addition

# %%
a=112

# %%
b=345

# %%
a+b
# Out:
# 457

# %%
a-b
# Out:
# -233

# %%
a*b
# Out:
# 38640

# %%
a/b
# Out:
# 0.32463768115942027

# %%
a//b
# Out:
# 0

# %%
a**b
# Out:
# ...

# %% [markdown]
# ### Precedence and Association

# %% [markdown]
# ##### BODMAS

# %%
a=12

# %%
b=56

# %%
c=a//b*a+b-a

# %%
c
# Out:
# 44

# %%
2**2**3
# Out:
# 256

# %%
89/12-45
# Out:
# -37.583333333333336

# %% [markdown]
# ### Assignment Operator

# %%
a=23
b=a

# %%
b
# Out:
# 23

# %%
a+=23  ##a=a+23

# %%
a
# Out:
# 46

# %%
a-=23

# %%
a
# Out:
# 23

# %%
a*=23

# %%
a
# Out:
# 529

# %%
a/=23

# %%
a
# Out:
# 23.0

# %%
a=a+1

# %%
a
# Out:
# 24.0

# %%
b=b+1

# %%
b
# Out:
# 24

# %% [markdown]
# ### Identify Operator ---->is,is not

# %%
a=23

# %%
b=23

# %%
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
a=[1,4,5]

# %%
b=[1,4,5]

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z=b

# %%
b.append(10)

# %%
z
# Out:
# [1, 4, 5, 10]

# %% [markdown]
# ### MemberShip Oprator

# %%
a=[1,3,4]

# %%
b=[1,3,4]

# %%
a in b
# Out:
# False

# %%
a not in b
# Out:
# True

# %%
6 in a
# Out:
# False

# %%
1 in a
# Out:
# True

# %%
2 in a
# Out:
# False

# %%
3 in a
# Out:
# True

# %%
2 not in a
# Out:
# True

# %% [markdown]
# ### Logical Operator

# %%
a=True

# %%
b=False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %% [markdown]
# ## ASCII

# %%
ord('A')
# Out:
# 65

# %%
ord('Z')
# Out:
# 90

# %%
ord('a')
# Out:
# 97

# %%
ord('z')
# Out:
# 122

# %%
chr(122)
# Out:
# 'z'

# %%
chr(112)
# Out:
# 'p'

# %% [markdown]
# ### Different print() function

# %% [markdown]
# ##### 1.Using Simple print()

# %%
#my name is atharv and my marks was 100

# %%
name='atharv'

# %%
mark=100

# %%
print("my name is ",name," and my marks is ",mark)
# Out:
# my name is  atharv  and my marks is  100

# %% [markdown]
# ##### 2.Using print() with :-

# %%
#my name is atharv and my marks was 100

# %%
print("my name %s and my mark is %d"%(name,mark))
# Out:
# my name atharv and my mark is 100

# %% [markdown]
# ##### 3.Using print() with format:-

# %%
print(f"my name is { name}and my mark is { mark}")
# Out:
# my name is atharvand my mark is 100
