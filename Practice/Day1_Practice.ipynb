# %% [markdown]
# # Practice

# %%
print("Hello") * 5
# Out:
# Hello
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print("Hello") * 5
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %%
print("hello"*5)
# Out:
# hellohellohellohellohello

# %%
print(12+45)
# Out:
# 57

# %%
a=2334
b=455
print(a+b)
# Out:
# 2789

# %%
a=23
b=45
print(a//b)
# Out:
# 0

# %%
type(a)
# Out:
# int

# %%
str1="hello"
str2="Python"
print(str1+str2)
# Out:
# helloPython

# %%
print(str1+" "+str2)
# Out:
# hello Python

# %% [markdown]
# ## Learn Data Type

# %%
list1=[1,2,3,4,'Atharv',23.56]

# %%
list1
# Out:
# [1, 2, 3, 4, 'Atharv', 23.56]

# %%
list1.append(67)

# %%
list1
# Out:
# [1, 2, 3, 4, 'Atharv', 23.56, 67]

# %%
list1.extend([1,2,4,5])

# %%
list1
# Out:
# [1, 2, 3, 4, 'Atharv', 23.56, 67, 1, 2, 4, 5]

# %%
del list1

# %%
a=complex(2,4)

# %%
a
# Out:
# (2+4j)

# %% [markdown]
# ## Perform Arithmetic Operations

# %%
a=23
b=45
print(a+b)  ##Addition
# Out:
# 68

# %%
print(a-b)  ##Subtraction
# Out:
# -22

# %%
print(a*b) ##Multiplication
# Out:
# 1035

# %%
print(a/b)
# Out:
# 0.26666666666666666

# %%
print(a//b)
# Out:
# 0

# %%
print(a**b)
# Out:
# 3657261988008837196714082302655030834027437228032

# %% [markdown]
# ## Program

# %%
##Swaping Two Number

# %%
a=12
b=34
temp=a
a=b
b=temp
print(a)
# Out:
# 34

# %%
print(b)
print(a)
# Out:
# 12
# 34
