# %% [markdown]
# # Practice

# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %%
sample=np.array([1,2,3,4])

# %%
sample
# Out:
# array([1, 2, 3, 4])

# %%
#Creating 0D Array -->Scalar

# %%
sample1=np.array(7)

# %%
sample1
# Out:
# array(7)

# %%
#Creating 1D Array -->Vector

# %%
sample1=np.array([1,2,3,4])

# %%
sample1
# Out:
# array([1, 2, 3, 4])

# %%
#Creating 2D Array

# %%
sample1=np.array([[1,2],[3,4]])

# %%
sample1
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
#Creating 3D Array

# %%
sample1=np.array([[[1,2],[3,4]],[[5,6],[8,9]]])

# %%
sample1
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [8, 9]]])

# %%
#checking of Array of 3D

# %%
sample1.shape
# Out:
# (2, 2, 2)

# %%
sample1.size
# Out:
# 8

# %%
sample1.ndim
# Out:
# 3

# %%
sample1.dtype
# Out:
# dtype('int64')

# %%
#Special Array

# %%
np.zeros((2,2))
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
np.ones((2,2))
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
np.linspace(1,2,5)
# Out:
# array([1.  , 1.25, 1.5 , 1.75, 2.  ])

# %%
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
# Accessing or Slicing

# %%
sample1=np.array([1,2,3,4])

# %%
sample1[0]
# Out:
# np.int64(1)

# %%
sample1[1]
# Out:
# np.int64(2)

# %%
sample1[1:3]
# Out:
# array([2, 3])

# %%
sample1[::]
# Out:
# array([1, 2, 3, 4])

# %%
sample[::-1]
# Out:
# array([4, 3, 2, 1])

# %%
# Math Function of array

# %%
np.sqrt(sample1)
# Out:
# array([1.        , 1.41421356, 1.73205081, 2.        ])

# %%
np.log(sample1)
# Out:
# array([0.        , 0.69314718, 1.09861229, 1.38629436])

# %%
np.exp(sample1)
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692, 54.59815003])

# %%
# Perform operation Maths on array

# %%
a=np.array([1,2,3,4])

# %%
b=np.array([5,6,7,8])

# %%
a+b
# Out:
# array([ 6,  8, 10, 12])

# %%
a-b
# Out:
# array([-4, -4, -4, -4])

# %%
a*b
# Out:
# array([ 5, 12, 21, 32])

# %%
a//b
# Out:
# array([0, 0, 0, 0])

# %%
a%b
# Out:
# array([1, 2, 3, 4])

# %%
# Random Module

# %%
np.random.rand(3)
# Out:
# array([0.70807101, 0.25829524, 0.02393745])

# %%
np.random.randint(1,10,3)
# Out:
# array([4, 7, 8], dtype=int32)

# %% [markdown]
# # Pandas

# %%
import pandas as  pd

# %%
series=pd.Series([1,2,3,4,5])

# %%
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series=pd.Series([1,2,3,5],index=[1,2,3,4])

# %%
series
# Out:
# 1    1
# 2    2
# 3    3
# 4    5
# dtype: int64

# %%
series=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])

# %%
series
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# Series Properties

# %%
series.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
series.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
series.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
s=pd.Series([10,20,None,40])

# %%
s
# Out:
# 0    10.0
# 1    20.0
# 2     NaN
# 3    40.0
# dtype: float64

# %%
s.dropna()
# Out:
# 0    10.0
# 1    20.0
# 3    40.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s.fillna(10)
# Out:
# 0    10.0
# 1    20.0
# 2    10.0
# 3    40.0
# dtype: float64

# %%
# Data Maniplate

# %%
s*4
# Out:
# 0     40.0
# 1     80.0
# 2      NaN
# 3    160.0
# dtype: float64

# %%
# Series Properties

# %%
s=pd.Series([1,2,3,4,5])

# %%
s.shape
# Out:
# (5,)

# %%
s.ndim
# Out:
# 1

# %%
s.size
# Out:
# 5

# %%
# Accessing Element Via Index and Slicing

# %%
s=pd.Series([1,2,3,4,5,6,7,8,8])

# %%
s[0]
# Out:
# np.int64(1)

# %%
s[1:5]
# Out:
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=9, step=1)
