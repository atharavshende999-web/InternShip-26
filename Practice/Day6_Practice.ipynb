# %% [markdown]
# # Practice

# %%
weekly_menu=(
('Monday','Dal','Rice','Roti'),
    ('Tuesday','Rajma','Rice','Roti'),
    ('Wednesday','Chole','Bhature'),
    ('Thursday','Aloo Gobi','Rice','Roti'),
    ('Friday','Panner','Naan'),
    ('Saturday','Palik Panner','Roti'),
    ('Sunday','Non-Veg')
    
)
weekly_menu[1][1:4]
# Out:
# ('Rajma', 'Rice', 'Roti')

# %%
##Find the monthly budget of hostek student using tuple

# %%
weekly=(
('Monday','Dal','Rice','Roti'),
    ('Tuesday','Rajma','Rice','Roti'),
    ('Wednesday','Chole','Bhature'),
    ('Thursday','Aloo Gobi','Rice','Roti'),
    ('Friday','Panner','Naan'),
    ('Saturday','Palik Panner','Roti'),
    ('Sunday','Non-Veg')
    
)
i=0
while i<=7:
    ch=input("Enter the day")
    if ch=='Monday':
        print(f"{ch} cha Menu:{(weekly[0][1:4])}")
    elif ch=='Tuesday':
         print(f"{ch} cha Menu:{(weekly[1][1:4])}")
    elif ch=='Wednesday':
         print(f"{ch} cha Menu:{(weekly[2][1:4])}")
    elif ch=='Friday':

        print(f"{ch} cha Menu:{(weekly[3][1:4])}")
        
    elif ch=='Saturday':
         print(f"{ch} cha Menu:{(weekly[4][1:4])}") 
    elif ch=='Saturday':
        print(f"{ch} cha Menu:{(weekly[2][1:4])}")
    else:
        break
    i=i+1
# Out:
# Enter the day Monday
# Monday cha Menu:('Dal', 'Rice', 'Roti')
# Enter the day no

# %%
##Monthly Kharach Tracker

# %%
Budget=int(input("Enter the Monthly Expense:-"))
list1=[]
remaining=Budget
while True:
    Daily_Exp=int(input("Enter the Daily Expense:-"))
    
    if Daily_Exp<0:
        break
    elif Daily_Exp>10:
        remaining=remaining-Daily_Exp
        list1.append(Tot)
        print(f" Daily Expense is {Daily_Exp} and Remaining Money are {remaining}")
print(list1)
# Out:
# Enter the Monthly Expense:- 9787
# Enter the Daily Expense:- -52
# []

# %%
##Dictionary-. "CAP College Finder Bot"

# %%
college_list={
'VJTI Mumbai':99.2,
    'COEP Pune':99.99,
 'PCCOE Akurdi':98.56,
    'AIMS Pune':95.26,
    'PICT Pune':99.99,
    'DY PATIL Akurdi':75.98,
    'SPPU Pune':90.56,
    'WALCANT SANGLI':94.23,
    'PCU Ravet':95.63,
    'VIT Nashik':97.56
}

ch=int(input("Enter Your Marks"))
list1=[]

for indx,cuttoff in college_list.items():
    if ch>=cuttoff:
        list1.append(indx)



print(list1)
